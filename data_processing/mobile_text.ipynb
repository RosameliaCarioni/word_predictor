# %%
import os 
import string
from nltk.tokenize import TweetTokenizer 
import re

# %% [markdown]
# This notebook handles the pre-processing of the dataset used in the paper: Mining, analyzng, and modeling text written on mobile devices, by K. Vertanen and P.O. Kristensoon. Paper:
# https://www.cambridge.org/core/journals/natural-language-engineering/article/mining-analyzing-and-modeling-text-written-on-mobile-devices/A60B599D7E92B5DB9CBDE243A80626C3
#
#
# It generates 1 .txt files with cleaned content named: `mobile_text.txt`.

# %% [markdown]
# # Methods

# %%
def clean_line(line):
    tokenizer = TweetTokenizer()
    line = line.replace("’", "'")
    allowed_punctuation_char = "'"
    allowed_punctuation_word = "'" + "#" + "-"
    
    # Modify regex to preserve periods in abbreviations like 'U.S.', 'P.M.', etc.
    # 1. Substitute periods in known abbreviations with a placeholder
    line = re.sub(r'(?<=\b[A-Z])\.(?=[A-Z]\b)', '', line)  # Remove periods in multi-letter abbreviations
    
    line = re.sub(rf'[^\w\s{allowed_punctuation_word}{allowed_punctuation_char}(\w+\'\w+)]|_|\d', ' ',  line)
    
    words = tokenizer.tokenize(line)
    result = ''
    for i, word in enumerate(words):
        if word in allowed_punctuation_char:
            result = result.rstrip()
            result += word.lower() + ' '
        elif word not in string.punctuation:
            translated_word = word.lower().replace('.', '')
            if len(translated_word) == 0:
                continue
            result += translated_word + ' '
    return result.rstrip()

# %%
def extract_sentences_and_clean_them(folder_path):
    sentences = []
    
    # Iterate over all files in the given folder path
    for filename in os.listdir(folder_path):
        # Check if the file has a .txt extension
        if filename.endswith('.txt'):
            file_path = os.path.join(folder_path, filename)
            with open(file_path, 'r', encoding='utf-8') as file:
                for line in file:
                    # Strip the <s> and </s> tags and any leading/trailing whitespace
                    stripped_sentence = line.strip()
                    cleaned_sentence = clean_line(stripped_sentence)
                    sentences.append(cleaned_sentence)
    
    return sentences

# %%
def write_sentences_to_file(sentences, file_path):
    try:
        with open(file_path, 'w') as file:
            for sentence in sentences:
                file.write(sentence + '\n')
        print(f"Sentences successfully written to {file_path}")
    except Exception as e:
        print(f"An error occurred while writing to the file: {e}")

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# # sentences folder
# #### This contains all the sentences extracted from data_1 and data_2 folders

# %%
sentences_path = '/Users/rosameliacarioni/University/MSc/1_year/4_period/language engineering/word_predictor/data/mobiletext/sentences'

# %%
all_sentences = extract_sentences_and_clean_them(sentences_path)

# %%
len(all_sentences)
# Out:
# 15302165

# %%
all_sentences
# Out:
# ['Is this reasonable variation',
#  'And whats the easiest editing software',
#  'Its useful life has been served so under the knife it went',
#  'This makes no sence',
#  'I got HF unit',
#  'We went to pick up the outback last night and the salesmen was going over the warrantee information with my parents',
#  'There is an option in Sync to turn autoplay off but it still plays on connect',
#  'We shall see I suppose',
#  'there was no noticeable wear on anything but for some reason it just wanted to short stroke after a few magazines when it warmed up',
#  'ie better protected from dirt water and debris',
#  'The Satellite radio is not so good but we all are aware of that issue',
#  'Pardon me but I was going to move it to the correct thread',
#  'Havent even tallied my putt count yet',
#  'on a positive side though from the motor forward i have to say AWESOME You could also make a depron box with a piece of elastic to go around your head',
#  'and will check ground tomorrow',
#  'Thats where Id be worried about a poly lower',
#  'Do it at your own pace',
#  'Just wanted send a follow up in case more globalgolf deals come up',
#  'I love my SCT tune from Kevin and AGP',
#  'Good price',
#  'Why not just put your stock injectors in',
#  'My opinion is that all those bells and whistles are going to either break or become obsolete',
#  'The Grizzly was my ride for the day',
#  'Thanks You can fit the dogger on the stock exhaust if you make the notches in the back plate the other way',
#  'I had the dealer look for one but no dice',
#  'what tyres does that guy deal with',
#  'I think he owns several BMWs',
#  'Lol if you need help testing hahahaha',
#  'Youre right',
#  'Again its a smooth tempo for me now as opposed to taking anything off my swing',
#  'Maybe variation like spncorn or sipncrn',
#  'Ryan its not as expensive as you think and well worth the extra money in my opinion',
#  'And I remember the point being made before what if I dont ground the driver and just hover',
#  'Best stuff Ive found Thank you guys will look into hypotherm',
#  'I havent had time to even think about videos or pics',
#  'Ive done a few monster jumps that i thought were the end of me and came out fine',
#  'Not too long to go',
#  'Let me know',
#  'I use chrome on my pc',
#  'Ill let you know',
#  'Those are notoriously inaccurate',
#  'What a nice bike',
#  'Most have hackd up wiring and vaccum line mess',
#  'Well they came rolling in today',
#  'added reverse but not sure what else',
#  'No damage to the car at all',
#  'I cant fault some for being on the course more than the forum because thats what they chose to do as a participant of the event',
#  'I replaced mine with aftermarket',
#  'We know shine Its fun for sure',
#  'Thanks though',
#  'Also raising pegs and moving bars forward will not instantly make a bike more agile',
#  'fuck you faggot',
#  'Did some research and found that plastic will do that',
#  'Kcboy for oil analysis its posted few pages back',
#  'She is skinny',
#  'I would bet that the car you just bought has a wiring harness that consists of bare copper wires rubbing together causing all kinds of fun issues and a fine dust that used to be insulation mixed among said bare wires',
#  'Wish me luck Sorry it was just this app Im using',
#  'It has alot of aftermarket parts on it so i didnt have to do anything',
#  'Usually its just bent valves',
#  'But it does come at the cost of drag and speed',
#  'Plasti what',
#  'Perfect for a nighttime TSD rally',
#  'It drives very light for its size and maybe attributed to the electronic steering',
#  'Now lets see if I can file to have my last switch I replaced reimbursed',
#  'Native or emulated',
#  'Hit them',
#  'Yesterday I really had to work on my taxes',
#  'Still for sale',
#  'Found some lights on Craigslist',
#  'Do not mash down the brakes on a hill when you stop',
#  'I bought a set of black housing over a year ago',
#  'Got call from dealer and the veredict is that I need a new transmission and torque conv',
#  'I had a tough front nine',
#  'Vacuum lines are solid',
#  'Well I dropped it off for repair and did other errands',
#  'When it goes you lose hazards and turn signals',
#  'What do you mean by if there is an issue',
#  'Food for thought on the backrest',
#  'And since I have the feeling that the valves are bent which will take some time and money Ill use that part for now',
#  'Wish it was as easy as the fcat',
#  'Get the cf hvac to finish it off man',
#  'The feel sound shaft and performance is just fantastix right now',
#  'It caused weird transmission shifting issues',
#  'This is from Michigan and our combination set ups are way different then most other states',
#  'then I DDed for some of my fellow sailors and that went out the window',
#  'If you are trying to avoid him hearing any tell tale signs one possibility would be to do it when there is enough noise coming from his room that he wont hear what you are doing in yours',
#  'think you should work on some way to make it strong enuff to not have the top part',
#  'I havent had any problems with my setup and I love the numbers',
#  'They were found in the house but that may or may not mean anything',
#  'I like to do this once in a while just before going to bed',
#  'This is a well respected benz dealer',
#  'Crank times for me havent been a problem',
#  'May have to stick with white but I think black with white lines may look cool with white shafts',
#  'It doesnt have to have anything to do with another part of the electrical system',
#  'How could you possibly rationalize the deduction that the US is not part of KWAs market share',
#  'Especially on the stock head and cams',
#  'I took mercy on his Mercedes soul and said to him to take the car to the guy I trust with my Benz',
#  'That is all I filled in I left all the other questions blank',
#  'I just choose not to drink',
#  'It just looks and feels so luxurious and rich',
#  'Very nice flight',
#  'It was given to me by a family member so they were pretty honest about it',
#  'If it hits that point the boost box will shut her down to spring pressure until you let off and go WOT again',
#  'Pics would definately help but unfortunately it would seem like you are on your way back to the vet',
#  'He should play the lottery if his story is true haha Is it illegal to have one',
#  'That eliminated the SAM module IMO',
#  'Needs a scuba tank Nope',
#  'The trunk looks factory',
#  'Wow already jumping to parents',
#  'Any water coming from the weep hole',
#  'I dont intend for this to become a full time job just something extra',
#  'That harness plugs into the factory radio harness',
#  'Its like rice crosses ghetto Thanks for the input',
#  'there isnt any vibration coming off the engine at all',
#  'The RO called me on it and I was quite embarrassed',
#  'Ill also look at the starter and alternator to see if its either of those',
#  'Okay kool thank you too all',
#  'I would love to find a short throw kit',
#  'Been there done that',
#  'Here are my complaints about it',
#  'do they still offer discount if you refer others',
#  'Mine came with degree shims',
#  'Reason for that is because im doing the flush thing to it',
#  'Cleans great and smells nice too',
#  'It was a photographer and even he said he thought he caused Bubba the crash',
#  'So yeah it boils my blood when I read this chit',
#  'Brake system is not',
#  'Removing more things I find more water leaks',
#  'Whats the final verdict',
#  'The Avett brothers are great',
#  'Out with the old',
#  'I think lemfordeder is OEM for many hard parts like these above iirc',
#  'Then the tuning process can begin',
#  'Glad for Stewart',
#  'That was a great post my friend',
#  'Although if the motor made it this long nikasil probably wont be a factor',
#  'flight to Orlando is going to be delayed The black looks real good',
#  'It is a sickle section from a hay mower',
#  'Believe it or but I actually manage to get them all out on the course throughout the year',
#  'Still trying to read up on this stuff',
#  'What exactly does this do',
#  'Talk to me Goose',
#  'We plan to leave here Friday night or Saturday morning headed for Mississippi',
#  'Besides ob is the fastest color',
#  'Got it back Wednesday',
#  'Save me from android',
#  'Just need a garage and air tools and compressor of course',
#  'I know he is being lied too so does he',
#  'I taped the ballasts down with the included double sided tape',
#  'no clicky',
#  'Sounds like you will have yourself a pretty sweet display case',
#  'Congratulations Jake',
#  'You most likely blowing it off out of the bov and spaying the engine bay Generally when you clay bar after waxing it will remove some wax more in some areas then others',
#  'Its a great tracking system they got there',
#  'Lol If memory serves you remove the seat switch to remove the door panel',
#  'Second every engineer I know has a firm grasp on the english language and knows how to spell',
#  'just bought it a month ago bcoz i just came to usa last month',
#  'make sure you have as little as possible to do the day before so you can rest up as much as possible',
#  'But I did drive a first Gen Honda Odyssey once to pick up family from the airport in their car',
#  'I would advise posting it on a Friday afternoon and letting us go wild',
#  'Maybe even use your water pump I found a complete YJ for CHEAP',
#  'Big and Black Is there such a thing as military grade when it comes to atvs for military use',
#  'Its just to plug a few security holes and maybe some odd bugs',
#  'The metal spikes are sharper than you can imagine',
#  'what is needed for members still active or reserve',
#  'He said what would you do if I turned out to be gay that to me sounds like a huge huge hint saying something about his sexuality',
#  'Let us know when you can confirm',
#  'Take it easy and take the classes',
#  'maybe the switch was stuck open and the oil light didnt work till this last oil change Id wanna put crazy eyes on my EX Does the engine rev but have no acceleration',
#  'What did you order',
#  'Got my magazine in today thanks',
#  'Im going to petronas now and malls aside from that ano pa',
#  'not sure',
#  'Ive never done one',
#  'I wanted to say thank you corey for taking care of my headlight problems so fast',
#  'What inspired me at the time were the comics that were full of it',
#  'All these heat shields',
#  'Im surprised plasti dip looks that good on rims',
#  'Call them to see if its still there or has been crushed',
#  'I can put a pry barr and see its free i',
#  'Practicing on dirt is better if you tend to fall backwards alot',
#  'Thats a mistake i made when buying it',
#  'Hi all I have been searching for a day or so to determine witch metal line is the fuel return line under the hood',
#  'Ive seen a couple guys running that timer with no problems',
#  'And Im keeping it stock bore',
#  'Did you have idle issues too',
#  'I did my rears',
#  'Thanks for the response if you do',
#  'Ok so ill try to explain in detail my issue',
#  'I have a similar grinder just not the safety green',
#  'Trying out the new app',
#  'Im jus goin to leave it their',
#  'I have flown this on my simulator and enjoy it',
#  'You guys can pull me if you need space',
#  'I heard they suck so Im going act Im not dealing with no feedback Because you have a boost leak',
#  'Good to be here',
#  'how would i do that please',
#  'I listen thru the autocom without having the stereo turned on',
#  'Haha you should buy it',
#  'I belive it ended up in the middle',
#  'It works on all surfaces',
#  'Damnit lol',
#  'Hope its not happening here too',
#  'I have to pick it up Monday night after work',
#  'Like i said so far its working like a charm',
#  'I have my carb totally apart right now cleaning it from bad fuel',
#  'If anyone is concerned about oil use check your pump calibration',
#  'God forbid someone actually try and HELP someone on the forums',
#  'Not sure if thats good or bad',
#  'I use them when i set up jigs',
#  'Means a lot to have all this support I had branch bundle block but echo looks good and stress test tomorrow soaybr I that is good get banded Friday',
#  'Plus the tach shuts off',
#  'Where the DVD now please update Thanks',
#  'Will post a full list later Ok sounds good',
#  'I was willing to accept it',
#  'If there might be one',
#  'And its not the leather as other cars I had have leather',
#  'they both look good to me',
#  'Ive already tried the local media',
#  'I need new floor mats',
#  'Have you found problem too solution',
#  'Thanks buddy',
#  'Time for me to find a new ball',
#  'All on s ski slope',
#  'Lol I think the msd r hit or miss cuz I heard both good and bad',
#  'There are a few threads on how long you can expect to wait',
#  'Nevertheless I still believe there will be someone for me and I do think shes gonna be an INTP or INTJ',
#  'Im settin here getting loaded right now',
#  'What do I need to make them fit and be safe',
#  'Nope Anyone use My Tracks for android',
#  'My Dr chalked it up to stress at the time for several reasons',
#  'Jayare Nevada is simple pass fail',
#  'Thinking about buying a used turbo and exhaust manifold for Srt does anybody on here know a shop that will port them both for me',
#  'Ill have to find out more when I pick it up',
#  'I still dont know what happened Dont force it',
#  'Give some moredetails',
#  'And think about What mods r next Literally the sluts suck Nice find',
#  'I tried turning it down and it wouldnt burn in',
#  'and the oil pump cant pump the froth and bad things happen',
#  'I have been to ottawa a few times wasnt sure if they would have snow',
#  'Then you said that there going to have the same engine as the caliber and not the neon',
#  'Im sure you dont get charged as per SMS for each message you send',
#  'The face and insert almost seem to have a hollogram or something on them',
#  'Not really in the way',
#  'Any opinions as to whether this will make an appreciable difference',
#  'Im really looking forward to seeing it all',
#  'They are Gcc guess I should have said that in they original post',
#  'But Im sure that one could not program it with STAR',
#  'Arctic fx doesnt charge that for wraps on their site',
#  'Routine maintenance will be done by a fellow Mercedes fanatic and mechanic now that the car cars age and mileage is a factor I do not take it to the dealer anymore',
#  'We usually just throw out our older pArts otherwise we would have no room to park in the garage here',
#  'then the raffle drawing',
#  'Im going to bring the cables up through the gromment just on the inside of the cargo area pretty much behind the tail light',
#  'Lol',
#  'I seen you ordered it from the group buy',
#  'Im just wondering if anyone has tried a top speed run without the top case and maybe its only limited with the top case connected',
#  'I think I may be the only person who never liked it to begin with',
#  'Will be bringing this back to the dealer first thing Tuesday',
#  'So once placed I use a popsicle stick to pass over the tape till it is nicely laid',
#  'Sounds like normal valve train noise to me',
#  'Im all updated',
#  'What is the basis of your pricing',
#  'Just a bigger motor Does any one have any ideas for a camera plane',
#  'Oh dear what a bizarre way to spend ones time were your comments necessary',
#  'They are duty holsters heavy and bulky but they work fine',
#  'Dunno why it bothers me so much but it does',
#  'Was really hard seeing someone else on my bike but it was time for it to go to someone who would ride it more than me',
#  'Amazing',
#  'If u have a cold side hard pipe with a aftermarket bov it should be teed to the intake manifold vac lines',
#  'Its not like any knowledgeable person could ever think this tablet could ever be comparable to an ipad or mainstream phone',
#  'These are what my mounts looked like',
#  'Thats where im at so far',
#  'Lol where did you find this',
#  'Ive been to a couple of RA rallies and met some truly awesome folks',
#  'A paper drill template will be included with the set',
#  'It fixed the back so it is level',
#  'You would think so but you want to see some of the parcels I get',
#  'The testing is free since Im buying shafts',
#  'No immediate or logical reason why I just feel more comfortable with the metz',
#  'Who wouldnt be pissed',
#  'Anyone catch that lady in the sec',
#  'not bamboo',
#  'Just in the back yard at night time when the neighbors are sound asleep',
#  'I found out that their maintenance geniuses had forgotten to replace the plastic cover in the right air channel',
#  'How would someone who does not have access to a miyazaki fitter go about getting the proper flex code in these hybrids',
#  'Ive heard it is more expensive then',
#  'Plus you can add a little color to it',
#  'I agree the subframe thing is just a bit of a project',
#  'PO took very good care of it',
#  'I have someone wanting to trade me for a Kahl albino boa',
#  'Interesting links',
#  'Fired her up for the first time since the rebuild had a really big leak at the intake manifold',
#  'See thats what I thought',
#  'I love the looks of the shoes',
#  'You gotta take a flathead and hammer it in between the cracks to break it open and glue it back with something strong',
#  'Does anyone know what this port is used for',
#  'Lol we are goin to need a new thread called What made it into OEM Kevins bag today',
#  'What did the install on the sights run you',
#  'Well after speaking very briefly with the shop I believe he said it was the fuel pump module',
#  'It may cause a bund when both wheels in the axle try to turn in the same section',
#  'Oh my',
#  'Will try to wire direct to the dome light wires',
#  'leave the wheels alone if bbs wanted them black they wouldve come black from bbsthemselves Your a retard',
#  'id rather live a short life getting thrown off a quad than a longer life of work eat sleep and repeat',
#  'Happy holidays',
#  'Perfect wording for my feelings on all of this',
#  'I barely touched my putt and it runs past the hole',
#  'Ive heard of it melting through film and seen that but I have yet to see that on a digital camera and I know a few people who will shoot without any filters',
#  'Working at putting all the details together now',
#  'I just went wot and held to full boost and when I let off the problem was gone',
#  'is there a way to bleed the clutch',
#  'Yes they could add that pin to the aftermarket harness if its found in the main radio plug but sometimes its found in a secondary plug or where ever',
#  'That sounds like a good idea I was thinking of possibly cutting my shift rod its self and making it shorter but I dont know its kinda of risky',
#  'Corbeau makes a lower seat bracket but once you add one of there seats its a little lower',
#  'Im new to the wheel world',
#  'I finished work early this morning and the weather was perfect for flying and I could not resist an empty field',
#  'Just realized that My favorite and most use lense',
#  'Jack is it possible to chain the dog outside',
#  'I couldnt be happier with the home they found either',
#  'Thats great',
#  'The ground has been a solid sheet of ice lately and the past two days its been pretty Ive had to work',
#  'first time i opened it there was quick and fast air pressing out creating an explosive sound almost scaring me to death',
#  'Recently my Coupe has gone through a metamorphosis even more so towards this ideal',
#  'I really like stance',
#  'I would start a new one if I could figure out how To from my cell',
#  'Youd think they would want my money but I feel fobbed off probably due to the fact Im a retail rather than commercial customer',
#  'Congrats cookie',
#  'Ill do it today and forward as I am advised',
#  'I have hot glued the mount into place with a few drops of glue then I went back and gorilla glued it in place',
#  'the hardest was the warning labels',
#  'Is it still rich',
#  'You gotta get those pesky mice Darren',
#  'Skippy The MLs wheel is proprietary',
#  'Miles',
#  'Going to try it tomorrow',
#  'There was just wildlife everywhere',
#  'And hot water to the solenoid valve under the hood',
#  'Phone is great',
#  'Meaning even if its working its not working hard enough',
#  'He might be trying to get you to refund the money first',
#  'IMO the feel is completely different',
#  'I never saw him come out of the hide but I thought he just came out while I was sleeping since he is nocturnal',
#  'this weekend trading the stock struts for skme BC coilovers',
#  'A happy ending',
#  'No idea why yours doesnt',
#  'City driving seems easier to drive',
#  'No idea on price though',
#  'You know just like the first iPhone',
#  'Could the valves have been so tight that it caused this or something',
#  'True Monkey spirit I suppose Nice info mine is metal thank goodness We shouldnt be eating packaged meats',
#  'Ill post more pics tomorrow',
#  'If that doesnt hit you wrong imagine if you opened this thread and it was your mother in the photo',
#  'I went to the putting green at Golf Galaxy and I loved the feel and roll that I got',
#  'And Id like to space it out and not overwhelm but even that',
#  'Liv and learn I spose',
#  'Hope this helps Yeah I havent had a problem with any of mine except for my tokays',
#  'They were the ones that originally mounted the neused tires on the rake last year and I have been back two times with flats',
#  'Had steak and rice last night',
#  'Its still long responsive and can be worked',
#  'Definitely going to enjoy a few beers tonight It passed',
#  'The steering column is made to collapse on impact in order to keep you from bring impaled by the steering wheel',
#  'Cant wait tosee what you think on course',
#  'Anything else from your experience with the CPO that I should double check',
#  'If you didnt get the running lights then your next thing would be up to you',
#  'Waiting patiently haha',
#  'is this just asthetic kit',
#  'Hell Ive even defended you on occasion',
#  'Or yes u could check for power',
#  'Dont really need a tune on low boost',
#  'But I use turtle wax ice myself',
#  'It started messing up and wouldnt let me do anything',
#  'Well cant multi quote on here but',
#  'I hope this makes sense',
#  'My car is almost a perfect rider now',
#  'Yup i think you should run the fuse side pieces all the way to the back for two reasons',
#  'Was gonna have them to an oil change and I decided to not bother right now',
#  'I did go to the how to stickies and found the write up',
#  'The performance seems a slightly better car',
#  'This spring ill give it a shot',
#  'Rust was just starting at the bottom section so Im glad I took the glass out',
#  'Hopefully those lines arent quite as bad',
#  'Because after that they are expected to fail',
#  'A dynamic test would tell you for sure',
#  'Did you add the dual in and dual out relay and the error thing',
#  'We bitched for years about the weight so lets add more shit to make em heavier',
#  'The buggies climbing the hills is not a every weekend thing either',
#  'If you had it it would be where that rectangle piece is located above the hazard light switch',
#  'Thats an awesome color',
#  'Well your on way too much boost',
#  'As if that explained why the sky is blue',
#  'Congrats and welcome',
#  'The rear skid plate is available and will reinforce the heat exchanger and the lower frame',
#  'Its strange how its only the passenger front side window',
#  'Let me know if you and your dad need a hand as I am not too far away from you',
#  'Holding a storage bag',
#  'Lol watch people rage about this too',
#  'Thanks for the input on my calcium worries there much appreciated',
#  'I even back away from the ball some and still hit the inside part',
#  'I got mine last july one day I just saw one on Craigslist and jumped for the hell of it',
#  'Of course all of this is jmho',
#  'So u are good to go as just a regular as any car No issues If the seller is the second owner then the first owner did not indicate the miledge on the title when the car was sold',
#  'I know it was a dumbass move but I thought maybe it was the throwout bearing and itd last my last week of school atleast',
#  'Or I may have to run new wires from the front',
#  'I am buying from MB of West Chester',
#  'Any word on the groups',
#  'Shes a real flying legend of her one time era',
#  'My brother actually got me a chain guides oilers and vc gaskets for christmas this is just a better option in my opinion',
#  'Yes I did replace it how likely is the tcm reset to fix my problem is there anything else that could be causing this',
#  'This is my mig',
#  'They remap and allow the inherent power designed into the motor to be realized',
#  'I opened the pic more and Im gonna say girl now Fantastic',
#  'as my friend has this tablet and wishes to go back to stock',
#  'Indeed I am interested',
#  'Froger towel work great wet on the inside and dry on the outside',
#  'please consider extra lights on your bike along with high vis colors on your gear',
#  'I had a local shop do mine',
#  'If your hitting full boost and it drives the same I think your alright',
#  'My buddy with his most broke trophy thatll work No problem',
#  'you didnt buy a thermostat you bought peace of mind for yourself your son and your Leo',
#  'Very reliable and the wagon comes in my handy than one would think',
#  'The T slots always work well',
#  'What saw do you run',
#  'If u really want to ride its definitly rideable',
#  'Sno cross race from bar to bar',
#  'I will be posting here regularly now so hit me with all the questions you might have',
#  'Either get a brand new bike or get the money back',
#  'Female driver',
#  'If you brake the front comes down harder',
#  'I tried Arthur Bryants twice once in ameristar and the other at the legends',
#  'It seems when I dont tighten the flash quite tight enough that it does the black bar thing',
#  'He is like the used car lot that has no lot',
#  'those ranges are very close',
#  'Not kidding',
#  'I used to have a spec v too',
#  'I think Im replacing mine this year just for good measure',
#  'You got me there',
#  'I loosened the line that goes to the screen but very little fuel comes out',
#  'I would think the ecu would be the last thing to go Flatside carbs or barrel carbs Very kewl',
#  'Hey stole this of one if the other threads',
#  'Traction is excellent which surprised me a little since theyre spikeless',
#  'They do good for a while and then all of a sudden struggle to stay alive',
#  'Did you weld up the vise stand',
#  'It got rough',
#  'I hear you on that I want a weld neck center shaft baaaaaaaaad',
#  'OH AND THE COVER OF TEARDROPS WAS JUST INSANE IN THE BRAIN',
#  'Heres a list of compatible barrels at the bottom of this website Yup this has been passed around for a few years',
#  'For example is the suspension beefed up or engine made with a higher grade part',
#  'I will be running the Laser Interceptor combined with a Beltronics STi R plus on my BRZ',
#  'The local supplier does a good job with fair prices if youve got quantity',
#  'Im not a fan of any of those',
#  'Just not durable or stain resistant',
#  'Nothing major to make a difference Wowzers',
#  'The draw face back then was hardwood and draw made up using face and half blind dovetails',
#  'I tend to add my baseball swing into my swing every now and then causing a fade which doesnt help',
#  'Putting the springb back wasnt tooooo bad I did have to chase the firing pin a couple of times though haha Committee report has been filed',
#  'What do you guys think about the oil',
#  'Start with the owner forst',
#  'Damn I just love how clean the engine is',
#  'The all black one was the sickest of the bunch',
#  'No problem',
#  'My next two trips',
#  'Cap when you said you rough them up',
#  'When buyer could not met the terms of the auction',
#  'They are super nice to deal with',
#  'Try that it should still be wastegate pressure',
#  'seems kinda high mine was rich bad with those same size jets',
#  'Use the same size bolts as what you remove from the kit',
#  'I got my stuff from him Wish it was man',
#  'Drive safe and see you soon',
#  'Im not an audiophile but even my wife knew something was different',
#  'They also indicated that Mercedes may have the advantage of knowing the intricacies of this type of issue from dealing with it regularly and thus would be better able to diagnose it',
#  'Ive been busy with other things',
#  'Parting a car takes time but can be worth it if you have the space and are willing to be patient',
#  'Anything about this car that I should know',
#  'Lets clear up some inaccurate statements here',
#  'Just what i needed',
#  'Not sure what you mean',
#  'Hell yes',
#  'Tub seats and roll bar',
#  'When you drive it the first time keep in mind they are new springs',
#  'Ill probably send it to them',
#  'I dont know if the service manual has the arm movement freeplay in it but i would check to make sure that is within spec',
#  'Oh yeah factory ammo feeds and chambers fine but Ive never looked for land marks on it',
#  'Island prices are getting too much',
#  'I plan to post a lot of content to this blog in July during my vacation',
#  'I swapped injectors yesterday and my misfire has come back again',
#  'I left AC a message since my dealer said that I would not have received anything since my survey',
#  'So the cats in the end were still the cause',
#  'That program last night did mention the use of flowers which represented different UK countries but nothing more exotic',
#  'Yea but he doesnt want to disasemble the entire thing',
#  'Also theres not much room for torque arms',
#  'Hopefully this gives some insight on what temp gauge should be at',
#  'is no better',
#  'I am jealous',
#  'at what price',
#  'Very nice review',
#  'Also put new primary clutch spring on and new original cam arms and hardware',
#  'I ordered a used engine computer can I just plug it in',
#  'Im winning this',
#  'Its an amazing guitar but I would shop around for a good price or even a used one if you can',
#  'I use rockplayer to play videos of any type',
#  'When was a tot we used to have all sorts made in Japan',
#  'And i used to love it',
#  'Anyone know how you include music and still be able to post to YouTube',
#  'I just might take you up on that offer',
#  'Interested Thats a good price',
#  'In my experience thats the only time leaks stop on their own but maybe youre just lucky and the leak healed',
#  'I cleaned sharpened and heated with a weed burner',
#  'Have tested the CPS with a meter',
#  'any auto part store should have that i guess',
#  'It doesnt lay flat at all and B',
#  'It starts up a lot better now and runs smooth',
#  'Out of a land rover That looks like the fuse for the amp',
#  'Wheres that from',
#  'Ha ha but yes Im planning on making to next one',
#  'So find a later unit if you can',
#  'Wheeled them on rocks and lots of road miles',
#  'Looks like the new part number comes with an extra rod',
#  'I rarely use my sidearm',
#  'Noisy upstairs neighbors who walk like they have cinder block shoes on',
#  'Finish him IN',
#  'Also gatorade water and nutrigrain bars first aid kit',
#  'You could justify that as in you have a unique name Any pics you have in mind',
#  'Look at the baseband version and that will tell you what modem you are using',
#  'I need to call and ask some of the big dogs around here',
#  'Too much sugar',
#  'and disgusting on the SRT',
#  'Give him two weeks to rest up and you never know',
#  'Im in the market for a shifter too Ive had my hids in fire a while stock housing just blacked out and Ive never had anyone bitch about them being to bright nor have I been flashed by any cars saying my hi beams were on',
#  'A little more pricey but a lot nicer',
#  'I admit I dont know what that is',
#  'Turns out I have tunnel problems as well as some others',
#  'Ill take the hippo tang if its still available',
#  'Ive bought some new alloys and the front passenger side wheel seems to be more straite up than the driver side wheel',
#  'My brother will be coming in from Houston in another car he is just going to take his off his mustang and bring them with him',
#  'I kept telling the owner his mechanics would put the lugs on too tight',
#  'Any way of testing it easily',
#  'Im not sure that it is being caused by the pedal',
#  'This doesnt answer your question but its a suggestion that will be echoed here quite a bit',
#  'I am rebuilding my stick motorcraft carb',
#  'All this just made my day reading its so funny I was just going to drop in the pistons and Rods',
#  'I called that shop',
#  'Not one single day has gone by without his input',
#  'I was amazed we got it done that fast on a Sunday',
#  'My final list',
#  'Got some numbers for u guys today',
#  'Thats nuts',
#  'Doubtful you will have problems',
#  'All of that is getting done next winter',
#  'Mind you I shipped the clubs to them the same day they told me mine was being shipped',
#  'Buy some flowers to the lady back home instead',
#  'Try it',
#  'Agreed Didnt make it last week will be there tomorrow way excited first run this year You only choice would be getting a bigger wheel put in the stock turbo Yea Im happy with the car and how it pulls',
#  'Its there',
#  'Like a trump card to pull',
#  'I am curious to here your honest opinion if it affected bottom end torque',
#  'After that I would say its done',
#  'If you dont mind what company is your car warranty with Please full out your profile with your year model and location do we can help you more',
#  'unbelievable',
#  'I would consider either one but I think they are classifed as kit lens just can be sold sperately',
#  'Yeah tonight is name dropping',
#  'Nice work',
#  'I know the laws first hand',
#  'I have priced it for a quick sale',
#  'I got my polishing kit in also and was gonna smooth out the inside casting in the mani and thought about gasket matching the turbo to mani',
#  'All the oil was coming from those three spots',
#  'What wire would you use that wouldnt have the lights on at the wrong time',
#  'there',
#  'How about sloppy owners',
#  'I dont have any photos but I know there is some great shots of action and videos available',
#  'He seems to think the stock options work better with that driver than after market options',
#  'I like the extended settings mods as well I have seen on many GB roms Apex launcher is the best I have tried',
#  'Mercedes says flush stuff like brake fluid where Chevy does not iirc',
#  'Sorry I should have made it clear',
#  'I got lucky',
#  'I am going to need a hand soon tracking down an electrical drawl on my truck',
#  'someone picked it up and gave it back to me',
#  'No rust',
#  'My wife hates the ride in the speedster we have',
#  'I found some used supreme tool powervalves for cheap so I just gave up on the servo',
#  'Next time you will show respect',
#  'I should be posting plans tomorrow',
#  'Ha Its your wastegate flapper rattling',
#  'Well kind of the same',
#  'Had a blast this weekend',
#  'Your car is sick man',
#  'The flange would be something that has to be welded on It started counting over again',
#  'Each stage has its own jets and adjustments',
#  'Thanks in advance',
#  'Would that make the motor shake violently while just sitting idle',
#  'Also my drive belt tensioner is making noise now which I think need to be replace',
#  'Anyway i disagree with your concerns about gravel',
#  'Thanks again oz welder keep on touch not many of us here from Australia',
#  'Nope that would be illegal',
#  'Just thought I would share',
#  'I really like this club for shots out of trees and whatnot though',
#  'Stupid exhaust item causes so many problems',
#  'I really hate that Im having such a rough time and hopefully it starts to come around here in the next couple of weeks',
#  'There is a drain on the passenger side that allows water to leak in through the fresh air vent',
#  'Usually I am all for a center shafted putter but I like how this one felt with the heel shaft',
#  'If time and money are endless go nuts with things',
#  'But yeah I agree you want be more careful',
#  'Here is the link on ebay',
#  'u may not know it all but u sure as hell know your way around our cars',
#  'Cluster changed means it was changed does not mean mileage was not altered to reflect actual mileage',
#  'For Bluetooth audio streaming does the Media Interface Plus add any benefits over the streaming that I believe is enabled in the COMAND unit through the latest firmware',
#  'Its really all on what you want to do and what will give you the most confidence standing over the ball with them',
#  'A Kitty kat got silver',
#  'if its traded in the next day doesnt do one thing',
#  'Thanks rowdie its a euro model',
#  'I seem to have heaps of room and dont seem to have the issues stated',
#  'The only place that requires a pass is old forge but Ive never riden there',
#  'you are required to overnight it',
#  'A gloved thumb holding it on a refrigerator for picture purposes',
#  'They should An antifreeze jug and hose makes for a good improvised one until you can find a better one',
#  'Very powerful but might be more then you are looking for',
#  'I bought one of those sanding mops ar a show but the refills and length of time it lasted were not cheap neither did they lasrt long',
#  'Dont be scared off because of high mileage alone on these cars',
#  'nothing wring here and think about this the cops arent going to run all over the country trying to find one guy',
#  'If they arent working do I need to replace the headlight wiper motor entirely or is it most commonly a fuse problem',
#  'Good luck on the walk thru tomorrow',
#  'The strong hit low bullets off the deck',
#  'In decent shape but is definitely drying out',
#  'Inside that folder make a new folder named audio',
#  'when its working',
#  'How is your power steering fluid level',
#  'Ive done it this way for as long as Ive been shooting and have never had this issue before',
#  'Very nice work The other problem you run into besides needing CV boot clamp pliers is that you either need to disassemble the outboard joint or have a tool thats used to stretch the boot over the large end of the half shaft',
#  'Me too',
#  'Not a good combo going uphill',
#  'This is what I determined what I did',
#  'It does look a bit too high and it is possible its been messed with',
#  'Do you have before and after pics',
#  'Im almost at the point of doing the entire install and then take to the dealer for them to tie it into the electrical system',
#  'Dont want to speak for all of us but its early yet for us to tell however PING irons are synonymous for lasting for a stupid long time so I anticipate it to look great throughout the testing',
#  'Sounds to me like theyve concluded you have hopelessly corrupted software as a result of the update and they dont think itll get straightened out by having you go through a bunch of gyrations with software updates',
#  'And oh my Bill take your ass back to the frozen tundra and stfu',
#  'Thats all I got',
#  'It is all marketing',
#  'We wont be in that area on the Saturday run but we can give you action similar to that if you are keen Can you post a pic of how u mounted on the lhs',
#  'Black and white with town car interior',
#  'The shape was throwing me off',
#  'We have a group in the greater Toronto area advertising this stuff',
#  'All the black looks new',
#  'Just gotta try and find someone local whos certified with sct or proficient with it I like them do I think they are a awesome car no but I do think they are a fun sports car just full exhaust intake and tune with some suspension mods maybe a brake kit n its a really fun car',
#  'Have you tried a little spin tilt',
#  'My fronts were originally KYB',
#  'From what Ive read here recently it seems that this is the single most fundamental change that is needed',
#  'Lol thanks for the help',
#  'What is the lead time on it',
#  'As for the comparison between this and a Raylor its not even close',
#  'Congrats to all who have ordered',
#  'Sometimes I wish we could chose what type of penis and testicles we want to have not what we are born with',
#  'Thats insane',
#  'I made it to the top and it was real steep at the very top so the tires dug in',
#  'Its my first car too',
#  'Getting my tax return back here shortly and I want to spend a little bit on modding my car',
#  'Im not sure of Im going to replace them as Ive also heard of airbags deploying well after the replacement date',
#  'I just fix one problem then another one comes up',
#  'i like it though',
#  'If its bad enoguh to cause that then who knows what else is up',
#  'Hahaha thanks for the kind words Chunky',
#  'Good luck',
#  'If it is shot its warrantied',
#  'Im not an engineer so hopefully you know what I mean',
#  'Actually they do work',
#  'I was just hoping one of you guys might advise me on a comparable or simply better knife than the ones I listed',
#  'Its the same reason infinity Lexus and Acura came to be',
#  'New name',
#  'I recommend the Diablosport line of products',
#  'On the iMac after hitting submit it takes you to a thank you for registering screen',
#  'It was a sim though',
#  'You gonna have any stickers with ya',
#  'After about one tank of gas total it should be set',
#  'Is it tobacco',
#  'Thanks for the links guys',
#  'I live in eastgate So just misfire codes',
#  'From what I can gather it look pretty easy I would just need to weld new plates to the bottom of the axle tube',
#  'Ill add head studs and bottleneck fix to my list',
#  'Hopefully it wont take too much to get it roadworthy',
#  'Also please fill out your user profile with your vehicle and location',
#  'Y did u fuck up ur dss axles',
#  'Hey kev have a chat to local LPG installer',
#  'I removed the rear caliper and cleaned out all the mud',
#  'Also see if Oxidized Black has a shop manual for your bike',
#  'Enjoy in good health',
#  'What is it with these troll type posts lately',
#  'Hehe I LOVE YOU mama',
#  'If you have one of Bobs custom Roms on there than than download the firmware from this site Bob has just released an Ics Rom for your tablet',
#  'Wipers worked but wb didnt',
#  'Maybe I need to change the other coil',
#  'If it hanging them constantly its iac',
#  'Nothing in the email they sent me Having hard time picturing but would like to do that',
#  'In my defense its noisier than normal because one door card in the back is not installed',
#  'Im gonna pass Ian',
#  'You lack character because you jumped down his throat right away without being provoked',
#  'I dont know where to start with this process though can someone help me out',
#  'Just take it to a grow shop and exchange it they dont seem to check the dates like the refill places or welding supply places at least they never have when I exchanged mine',
#  'I immediately get off the throttle when I see it start coming on',
#  'I have a cherry picker and chain',
#  'General low oil pressure loosing prime when sitting for a tad',
#  'If any of those make it go down you have just narrowed it down to the switch',
#  'Love you videos',
#  'Im sure hell be back sorting us out soon enough',
#  'I would just replace the harness anyways',
#  'had a great time',
#  'Woundering if i just need to drain and refill or if it fouled my plugs aswell',
#  'Question is how much sooner will it wear out',
#  'Yuck Not sure at this point',
#  'one of the skills a beginner often lacks is listening',
#  'This is a perfect opportunity to use up all those parts and scraps in the corners of the shop that were a bit too good to chuck',
#  'Which intake grate are you using If the piston has grooves how are the cylinder walls',
#  'I believe the rear skid is the same as the iq shift',
#  'New tires to follow',
#  'Good luck',
#  'Ill be building something with it',
#  'The Spyder felt almost as good as the Coupe',
#  'Again recap',
#  'Ive fixed a number of flash drives that I thought were dead with that',
#  'Pm them and ask about a price',
#  'Could also be as simple as bad gas ie water in the gas',
#  'Never let anyone tell you anything',
#  'Ive noticed after I shower a little bit comes off around the edges each time and I want to shower today but worried about all of the glue coming off',
#  'Whats your current suspension setup',
#  'Not a troll and not sarcasm',
#  'The idea is for the plane in a dogfight to pitch up to let the trailing enemy plane pass then realign the nose to fire on it',
#  'Wrong actually the black and still moving ones are the most nutritious theres the ones with the most calcium',
#  'Its to my knowledge the glass is not adhered to the car at all that the chrome strip holds it down with the rear seal',
#  'im no good',
#  'You will need a SYE kit and the guards kit out',
#  'That attaches to your bike seat or on your back',
#  'So no tuning just pulls',
#  'I just finished a stupid range session myself and may never go back',
#  'you sound nutz',
#  'I believe that theres a new type of tomahawk with loiter capability and they were getting rid of old stock',
#  'Hey mate',
#  'My veiw right now out side Ok so how forgiving are these for you folks whom have hit them off grass and more than once also what is your HC',
#  'Il turn the temps down slightly but this is how its always been i just set the light to come on more as its really cold in the room',
#  'I dont need extra info about the polar shift I have done extensive research on the subject and I think I am as up to date as possible as a civilian',
#  'Hey when we was kids we climbed trees so furniture was left alone or behind felt it besides we were not kept indoors like the kids today poor things',
#  'The folding stock is what appealed to me',
#  'Op has wired into coilpack per the original directions',
#  'Not a meteorologists but I bet he has a weather app on his iPhone',
#  'Tips for use would be to place a brush load on the blade and sponge and then use a womans square makeup sponge to spread',
#  'What about for rotors or are the oems solid',
#  'One of the main benefits of rooting is the ability to flash custom roms',
#  'To me same day ship means the they are sending it out the door that day',
#  'I though am jealous of your wolf hybrid sir',
#  'Thanks for sharing the link Dan',
#  'Thats good to hear',
#  'It takes a little time to do but it works well',
#  'Freakin work',
#  'Im glad I could help',
#  'The recoil spring in my RAMI P is pretty stiff',
#  'If your going to put it under the car the wrap it in electrical tape and plastic bag and the ziptie shut',
#  'but hopefully someone will post up service info',
#  'I covered my car up today because its about to monsoon outside and my sunroof has a leak',
#  'Your help is very appreciated',
#  'That makes me nervous but it is what it is',
#  'Books filled with maintenance receipts',
#  'Lol what turbo parts does he have to remove for tranny',
#  'when I signed up I knew I was getting a ball to test out and share my thoughts',
#  'Siri makes me happy driving home from work',
#  'Wants bike for a week',
#  'I like these wedges',
#  'My Tamron is outstanding and quite portable',
#  'She said yes anytime it has to be opened its pretty much a blanket cost',
#  'Looks like it can work for the Quads too',
#  'Sometime this is good for client check how the image will look like and not disturbed the shoot',
#  'Thanks for the info ill try ASAP Ya my desk is messy',
#  'Just wondering if anyone has rode today',
#  'Check valve between the pump and nozzle',
#  'Also get an adaptor plate to make it look like a stock install',
#  'That way you both would own something really rare',
#  'A two or three week spread for me',
#  'The first trailor is a heavy duty home made though Oh mercy that snow looks so inviting',
#  'I hadnt had the opportunity to hit an Adams when I was able to try the mashie a few months ago and my memory sucks so I could not remember the impact sound',
#  'Patrick Hi',
#  'I can take out the new key put the old one in without turning it pull it right out put the new one in and it works fine',
#  'Unpaved it is mostly crushed limestone which cover our bikes our gear and most of ourselves',
#  'It looks mean',
#  'What model did you get',
#  'That is what I am doing with mine when I get them rebuilt why dont you start a gay thread instead of turning all the other threads gay',
#  'It may be more economical for now to fix the E class AC issues at the least to have a car you aare familiar with especially if you are limited on funds',
#  'Sounds like some one with access to a Cnc machine could have a good little business going',
#  'Could I be a pest and ask one question',
#  'Hard to say',
#  'Also they seem to not fit perfectly or is that just how they are',
#  'Im then going to run both cables down the back of the tray and down the chassis rails zip tied to the brake lines',
#  'You could tell on mis hits the club would twist more with the weight then without it',
#  'Ive got a blanket on me cuz its colder than fawk in here lol',
#  'What about Friday practice',
#  'Will post up dyno graphs and videos soon',
#  'But you will get a few keepers',
#  'I thought you put it where the factory sub was',
#  'All these people on the forum and you Ask Him on a date',
#  'Im just hoping that its something as simple as replacing the alt and not a wiring issue',
#  'They must have just changed the premium membership because before I could view everything',
#  'Or the apparent lack thereof',
#  'What a blast',
#  'They appear to be identical',
#  'Seems to happen most often when Im riding in town with visor up',
#  'I have all the exact same symptoms as the op',
#  'Some people have used expanding foam between the panel and the pocket to help secure it',
#  'I tried to go to a new spot today but RAC was working at darkwater rd',
#  'thanks in advance Its quite possible you knocked some sense into the cat',
#  'Welcome you have come to the right place for knowledge',
#  'I wonder how my nerfs would have made out',
#  'I like the look',
#  'If not that makes it easier and maybe you should just trust theyll support you',
#  'Nada yellow is fantasy land and car dealers would be thrilled if people paid for cars based upon this',
#  'Impressed with the Tour Stiff stock shaft too',
#  'Each song volume would be the opposite of the previous',
#  'Thinking about it',
#  'Any idea how to diagnose the issue',
#  'The SL is just fine in the rain from my experience',
#  'Wow Frank quiet the big step',
#  'I dont have AAA',
#  'I have the same steering wheel cover in my impala',
#  'Keep holding it and plug your tablet into your pc',
#  'What i really like about your projects is just how well you meet the fit for purpose specification',
#  'I was draining some putts with it but again it was on an indoor putting green',
#  'The white sti pulls it off but I dont no if we do',
#  'Drugs or not that is someones son grandson brother',
#  'Im aware that people will post in the appropriate threads of the forum about which clubs there interested in',
#  'Time for this stuff to go',
#  'Looks good dude',
#  'Pentax couldve at least provide a metal mount',
#  'However I have read where some people did wait and the problem never went away until they got s new iPhone',
#  'Also my boost kinda flutters or surges at certain rpms under light to moderate throttle sometimes',
#  'That would certainly add control',
#  'Nothing to see here just keep posting everyone lol I have never been successful in running a chain drive on jackstands as the chain seems to load up then unload and makes a nasty clanking noise especially when i let off the throttle',
#  'Interestingly enough OReilly offers a metal replacement piston as well as the OE style phenolic',
#  'second only to the Viper',
#  'Would I never buy one',
#  'It was an mistake dismiss it I have a lock on my door but my parents usually leave me alone when my door is shut and if they need me they either text me or knock Ea will be killer awesome for android devices',
#  'I did take some pictures though',
#  'It appears that the key chain has changed',
#  'Grabe layo ng airport',
#  'He doesnt need that shit',
#  'There is nothing you can dose to get rid of them many people use kalk paste boiling water or lemon juice to cover and inject them with',
#  'Do a leakdown as well if compression is bad',
#  'Coolant temp sensor for auxiliary fans may be bad',
#  'The temp sensor IS the one on the tstat housing next to the vacuum valve for the EGR right',
#  'Haha Try shopping in sacramento',
#  'i had ordered a hurst then backed out nd got a mopar',
#  'I was intimidated by it the first time and now I dont give it a second thought',
#  'The guy at the dealership said it wont take my vin if one is already on there',
#  'Alpine sounds like Crap Android thru the autocom sounds fine',
#  'Off the grass I wasnt loving it today',
#  'Yea not a family car too small for that',
#  'I want to print one off at a print shop for once',
#  'Slammed cars of any make with body kits is Not my cup of tea but when it is done tastefully it doesnt offend like yours',
#  'Took mine out today and a couple of things came up',
#  'Had it not worked I imagine I would have been in deep shit',
#  'I almost died laughing',
#  'Im so excited to hit this one',
#  'All will be thrown on hopefully this weekend Msd wires arent bad its the coils that are junk',
#  'I like the vstream because I can clean the bugs off after every trip and it still looks like the day I bought it',
#  'The mirror sustained no damage even though it was knocked out of its normal position',
#  'Bayonne NJ',
#  'The trio of doom',
#  'Mine was built on a Tuesday before a full moon so I havent had this happen',
#  'All information and links were very helpful thanks everyone',
#  'I have yet to feel the suspension is inadequate on mine',
#  'I attribute that to the shaft but I dont know if its just me',
#  'As far as the cooling I had to run the hose up and over the secondary clutch like yours is',
#  'if that is the problem',
#  'I am going to check my plugs and filter this week as I suspect that is still a little low',
#  'Your writing and pictures have given me a smile',
#  'Do you hit the three iron differently depending on the wind if so how easy did you find it',
#  'There is a way to get more power easiest way to get more power is to put bigger fuel injectors I do have a code for smog pump',
#  'I think it was a parasite or illness that was present before I purchased him',
#  'Locate it in a central hallway and have it thermostatically controlled',
#  'IPod sounds good and best of all the Sirius is actually decent enough to listen to now',
#  'They supply the serious contractors and the quality of their stuff beats the borg junk in my view and at much reduced prices',
#  'They really are just right flex wise for me',
#  'Sounds like a much harder ball',
#  'Thanks in advance fellas any thank you so much for your help so far Patience grasshopper',
#  'Did u roll and pull urself',
#  'You may have to reconfigure a few that is all',
#  'Cuz I think I seen u at SAMs',
#  'First is the general mess of fitting all the scrap into something useful',
#  'Thanks director ill attempt this tomorow and see how it goes',
#  'I need to figure this one out though',
#  'Yes you can put regular but its not recommended',
#  'How about Nanny Wars',
#  'You could make a lock somehow so the window cant open more',
#  'Yun Sa city Lang ha genking hinde ako interasado doon saan meron mga petshop dito saka north face products',
#  'Thank you Jim',
#  'The leverage is good and no fingerprints',
#  'like dan said some are good and some arent',
#  'I was planning on putting projectors out of a BMW in but after seeing how long they were I didnt even bother',
#  'I adjusted without a rider on the machine',
#  'As soon as u get off the hill it gets rough',
#  'And so it begins boxermad',
#  'You will see a small round thing with two big and two small terminals',
#  'One is a local the other is Italian and from Amsterdam NY',
#  'Bulldog agrees with bullfrog',
#  'Ill update in a bit with the results',
#  'As for the wheels someone said they were clk wheels too',
#  'Very addicting',
#  'If so hows fitment',
#  'Worked like charm Ive seen them on craigslist like this',
#  'Thanks Go Wylde',
#  'Im no where even remotely close to a machinist but I have built several implements',
#  'Im trying to prevent everyone I know from dumping LiveProfile for Whatsapp or another client that already supports group chat',
#  'Why the big jump',
#  'Got built with new ones Im going to give it a try for a few months things are being put into action will have full details before long',
#  'I have half a tank of fuel',
#  'think Im gunna just hit up advanced auto in town and grab some of those ceramics though',
#  'There is an article in this months issue of crawler mag',
#  'Do you do it by trial and error',
#  'I might be able to go again',
#  'I got rid of those springs rather quickly due to blowing rear struts',
#  'Since mine has changed I teach high school science and history no more coaching',
#  'Being they were your first eggs I would say infertility',
#  'Someone had a bad day today',
#  'I wish I was going sooner than I am but work dictates my vacation schedule',
#  'I bought some reflector material stickers from my auto parts store cut to fit the shape of the raised area and stuck it on',
#  'Good to know about Seidio I was not familiar with them until I recently bought the Innocase Active Case Limited Edition',
#  'You know what Dave we trailer our cars to these tracks not because we dont want to drive them and sit in traffic get them wet ect we do it because god forbid it breaks the tow home is downright expensive',
#  'So I was right and the problem with the cooling was simply too many adapters and just too much mess',
#  'Saw a midnight blue gtl on dragon today',
#  'Ill get the battery checked out',
#  'Could be your Valve Body',
#  'I was more or less just excited to ear they have actually acknowledged that there is indeed a problem',
#  'You just snap offers a new blade tip when needed',
#  'I will be calling them now',
#  'I dont know that any of us went with the stock grips David',
#  'Interestingly enough the Tour X Stiff shaft performed very nicely',
#  'But google did',
#  'I love this move',
#  'I wouldnt worry about car sitting for long time as longest oil was changed',
#  'Post pics or ur a liar',
#  'I thought as much',
#  'Awesome Will congratulations bro',
#  'Thats the only software that can truly tune a Diablo tuner',
#  'Its supposed to rain all day right',
#  'Do not repeat do not take to MB dealer unless your funds are limitless',
#  'Finally Got it',
#  'Im thinking fuel pump',
#  'anyone have any experience',
#  'He didnt think that those compression numbers indicated anything that bad',
#  'On the must try list though',
#  'Ill have my part of the MATT video up tomorrow as YouTube isnt playing well with me tonight',
#  'I added ailerons onto the back of the wing rather than cutting them out of the wing and it really is nice',
#  'We humans sure know how to make short work of things it takes years for nature to create',
#  'What site are you using to look for your parts',
#  'Are you familiar with this engines',
#  'What could cause that',
#  'Im looking for a way to bring the spring back to my front seats',
#  'Bryan you got my attention with the word rolltop',
#  'Grandma was from South Africa',
#  'My question basically is which needs vacuum only and which needs vacuum and boost',
#  'and not dump a ton of money into as it is my dd Not bad not bad',
#  'Hope this helps',
#  'thanks for your replies',
#  'Full marks for wit on that one LOL',
#  'You can actually feel the breeze on your feet a little bit with all the mesh in the shell',
#  'Unfortunately the garage on base closed before I could rinse the flush out a second time so I just ran straight water in it for about a week',
#  'Love Them',
#  'They are available in different thicknesses',
#  'This thread is about a completely unrelated topic and your post will likely be disregarded',
#  'Mine will get low after awhile to I dont have any leaks and it dont burn it someone told me its normal',
#  'So just trying to soften this thing up as much as I can now',
#  'Usual suspects in cruise control failure are wheel speed sensors brake light switch and cruise amplifier',
#  'I wish you were an eye doc in my neighborhood',
#  'That should help her drive straight',
#  'The fact that you think we carry wooden clubs and drag women back to our caves says a lot about you',
#  'So I think its a good buy',
#  'Sana itll last few years nga',
#  'And you have to register every other year',
#  'Ohhh you had than nice black one',
#  'Seems like any possible chance I had was overshot with some other importance',
#  'Anyways Im sure ill be up there at somepoint dollar wise lol',
#  'But Ill need to send the bed plate for the straps',
#  'Hit these again tonight at the range',
#  'These gloves have shot way up my shortlist',
#  'Sometimes they work right sometimes not the dimmer switch not grounding does weird stuff too',
#  'I hear road cuts fuel as well as closes tb',
#  'blocks in back',
#  'I would check the SAM module under the rear seat to see if it got wet',
#  'I have a complete car white with dark tan interior',
#  'I would just like something a little better',
#  'no need to cap the noid',
#  'Damn where at',
#  'This was exactly the information I was looking for thanks katnapinn',
#  'I leave the bottoms uncovered but butted up to a steel plate covered with a thick scrap of plastic',
#  'Im not wishing it on his family I just want him to know that people are still people',
#  'Some amazing woodworking involved here',
#  'Well If someone ever wants a random picture completely over analyzed for no reason',
#  'Which tire blew',
#  'We must have the same group of friends cuz that was my BP exactly',
#  'What they say where there is a will there is a way',
#  'But maybe the can bus needs resetting',
#  'Tough greens with sticky rye grass on the collars',
#  'It was a custom one they guy made for it before I bought it and was very thin and bendable',
#  'I did this method on mine a while back',
#  'Was that eclipse AWD',
#  ...]

# %% [markdown]
# ## Store the content

# %%
output_file = '/Users/rosameliacarioni/University/MSc/1_year/4_period/language engineering/word_predictor/data/clean_data/mobile_text.txt'
write_sentences_to_file(all_sentences, output_file)
# Out:
# Sentences successfully written to /Users/rosameliacarioni/University/MSc/1_year/4_period/language engineering/word_predictor/data/clean_data/mobile_text.txt
